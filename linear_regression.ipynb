# %%
# !git clone https://github.com/tajuar-akash-hub/Datasets
# Out:
# fatal: destination path 'Datasets' already exists and is not an empty directory.

# %%
import pandas as pd
df= pd.read_csv('/content/Datasets/Housing.csv')
df.head()

#copy df for future use

copy_df = df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
df.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %% [markdown]
# # To see all unique value from specific feature

# %%
df['furnishingstatus'].unique()
# Out:
# array(['furnished', 'semi-furnished', 'unfurnished'], dtype=object)

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
enc = OrdinalEncoder()

df['mainroad'] = enc.fit_transform(df[['mainroad']])
df['guestroom'] = enc.fit_transform(df[['guestroom']])
df['basement'] = enc.fit_transform(df[['basement']])
df['hotwaterheating'] = enc.fit_transform(df[['hotwaterheating']])
df['airconditioning'] = enc.fit_transform(df[['airconditioning']])
df['prefarea'] = enc.fit_transform(df[['prefarea']])

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3       1.0        0.0
# 1  12250000  8960         4          4        4       1.0        0.0
# 2  12250000  9960         3          2        2       1.0        0.0
# 3  12215000  7500         4          2        2       1.0        0.0
# 4  11410000  7420         4          1        2       1.0        1.0
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0       0.0              0.0              1.0        2       1.0
# 1       0.0              0.0              1.0        3       0.0
# 2       1.0              0.0              0.0        2       1.0
# 3       1.0              0.0              1.0        3       1.0
# 4       1.0              0.0              1.0        2       0.0
#
#   furnishingstatus
# 0        furnished
# 1        furnished
# 2   semi-furnished
# 3        furnished
# 4        furnished

# %%
#here rank matters

rank= ['unfurnished','semi-furnished','furnished']   #for furnishing status doing the encoding

oe =  OrdinalEncoder(categories=[rank])

df['furnishingstatus'] = enc.fit_transform(df[['furnishingstatus']])

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3       1.0        0.0
# 1  12250000  8960         4          4        4       1.0        0.0
# 2  12250000  9960         3          2        2       1.0        0.0
# 3  12215000  7500         4          2        2       1.0        0.0
# 4  11410000  7420         4          1        2       1.0        1.0
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0       0.0              0.0              1.0        2       1.0
# 1       0.0              0.0              1.0        3       0.0
# 2       1.0              0.0              0.0        2       1.0
# 3       1.0              0.0              1.0        3       1.0
# 4       1.0              0.0              1.0        2       0.0
#
#    furnishingstatus
# 0               0.0
# 1               0.0
# 2               1.0
# 3               0.0
# 4               0.0

# %%
#to see the distribution

import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
sns.distplot(df['price'],bins=50)
# Out:
# <Axes: xlabel='price', ylabel='Density'>

# %% [markdown]
# # **MY version **
# # area vs price distribution check
# #using different graphs

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.ticker import ScalarFormatter

# Scatter plot of area vs price using the original dataframe (df)

plt.figure(figsize=(10,6))

sns.scatterplot(x='area', y='price', data=df, color='blue')

plt.title('Scatter Plot of Area vs Price')

plt.xlabel('Area')
plt.ylabel('Price')

# Ensure y-axis displays the actual price values without scientific notation

ax = plt.gca()
ax.yaxis.set_major_formatter(ScalarFormatter(useOffset=False))  # Disable scientific notation
ax.ticklabel_format(style='plain', axis='y')  # Set plain formatting for y-axis

plt.show()

# %% [markdown]
# # **some usefull codes to check ,  specfic value , max , min ** **

# %%
# Filter the dataset for area = 2000
filtered_df = df[df['area'] == 2000]

# Display the price for area = 2000
print(filtered_df[['area', 'price']])

# Find the maximum and minimum values for 'area' and 'price'
max_area = df['area'].max()
min_area = df['area'].min()

max_price = df['price'].max()
min_price = df['price'].min()

# Display the results
print(f"Maximum Area: {max_area}, Minimum Area: {min_area}")
print(f"Maximum Price: {max_price}, Minimum Price: {min_price}")


#to look out for spefic value
df[df['price'] == 13300000]
# Out:
#      area    price
# 498  2000  2660000
# Maximum Area: 16200, Minimum Area: 1650
# Maximum Price: 13300000, Minimum Price: 1750000
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3       1.0        0.0
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0       0.0              0.0              1.0        2       1.0
#
#    furnishingstatus
# 0               0.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Scatter plot using seaborn
plt.figure(figsize=(10,6))
sns.scatterplot(x='area', y='price', data=df, color='purple')
plt.title('Scatter Plot of Area vs Price')
plt.xlabel('Area')
plt.ylabel('Price')

# Ensure y-axis displays the actual price values without scientific notation

ax = plt.gca()
ax.yaxis.set_major_formatter(ScalarFormatter(useOffset=False))  # Disable scientific notation

ax.ticklabel_format(style='plain', axis='y')  # Set plain formatting for y-axis

plt.show()

# %% [markdown]
# # ques : what we can see after seeing the distribution ?

# %%
#now let's go for heatmap

sns.set(font_scale=2)
plt.subplots(figsize=(30,30))
heat_plot=sns.heatmap(df.corr(method='pearson'), annot=True, cmap='RdYlGn',annot_kws={'size':20})
plt.yticks(fontsize=35)
plt.xticks(fontsize=35)

plt.show()

# %%
x =  df.drop(['price'],axis=1)   #here goes our "feautures" because we are droping our price from here

#axis=1 specifies that you are dropping a column (as opposed to a row). If you set axis=0, it would drop rows instead.

y = df['price'] #this is our "target" , we are only taking the price , which we want to predict

#note
#you can remove some feature , which are not co-related

# %%
print(x.shape)

print(y.shape)
# Out:
# (545, 12)
# (545,)

# %%
#train , test spllit

from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.2,random_state=42)    #0.2 means 20%

# %%
#size of of x_train and X_test

print("length of x_train ",len(x_train))

print("length of x_test ",len(x_test))
# Out:
# length of x_train  436
# length of x_test  109

# %% [markdown]
# <h1> <font color= "yellow">
#  Must read the documentation :
# </h1>
#  https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html

# %% [markdown]
# <h1> <font color= "yellow">
# # normalization : <br>
# # MinMaxScaler : MinMaxScaler scales the data to a fixed range, typically between 0 and 1.
#
# <h1 font color="yellow"> note : never scale target only scale feature , why?
#  </h1> <br>
# # why we need it ?
# ans :
#
#
# </h1>

# %%
from sklearn.preprocessing import MinMaxScaler

scaler= MinMaxScaler()

x_train= scaler.fit_transform(x_train)
x_test= scaler.fit_transform(x_test)

#x_trian = subset of features, train the model
#x_test = subset of features , test the model

#y_train = subset of target variable "price"  to train
#y_test = subset of target variable "price" to test

# %%
x_train
# Out:
# array([[0.29896907, 0.4       , 0.33333333, ..., 0.33333333, 0.        ,
#         0.        ],
#        [0.3814433 , 0.4       , 0.33333333, ..., 1.        , 0.        ,
#         0.5       ],
#        [0.14886598, 0.2       , 0.        , ..., 0.66666667, 0.        ,
#         0.        ],
#        ...,
#        [0.19587629, 0.4       , 0.33333333, ..., 0.33333333, 0.        ,
#         0.        ],
#        [0.16426117, 0.2       , 0.        , ..., 0.        , 0.        ,
#         1.        ],
#        [0.26460481, 0.4       , 0.33333333, ..., 0.33333333, 0.        ,
#         0.5       ]])

# %%
df.head()  #see scaled data
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3       1.0        0.0
# 1  12250000  8960         4          4        4       1.0        0.0
# 2  12250000  9960         3          2        2       1.0        0.0
# 3  12215000  7500         4          2        2       1.0        0.0
# 4  11410000  7420         4          1        2       1.0        1.0
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0       0.0              0.0              1.0        2       1.0
# 1       0.0              0.0              1.0        3       0.0
# 2       1.0              0.0              0.0        2       1.0
# 3       1.0              0.0              1.0        3       1.0
# 4       1.0              0.0              1.0        2       0.0
#
#    furnishingstatus
# 0               0.0
# 1               0.0
# 2               1.0
# 3               0.0
# 4               0.0

# %%
print("length of x_train",len(x_train))
print("length of x_test",len(x_test))

print("\n \n ")

print("length of x_train",len(y_train))
print("length of y_test",len(y_test))
# Out:
# length of x_train 436
# length of x_test 109
#
#
#
# length of x_train 436
# length of y_test 109

# %% [markdown]
# # Let's start linear regresion

# %%
from sklearn.linear_model import LinearRegression

reg = LinearRegression()

# %% [markdown]
# # y=Wx+b
# W is weight(slope) b us bias (intercept term / constant)

# %%
reg.fit(x_train,y_train)       # x = features, y = target

#using train dataset to train model
# Out:
# LinearRegression()

# %% [markdown]
# *fit_intecept* is used to allow y intercept
#
# copy_x makes a copy of the features

# %%
y_pred = reg.predict(x_test)

# %%
new_y_pred = reg.predict(x)

# %%
y_pred
# Out:
# array([ 6029364.42476201,  8067824.45895751,  3118831.46433531,
#         4728026.66447905,  3436314.07249681,  3839103.74703785,
#         6034081.53284037,  7182730.79551024,  2761793.45904681,
#         2693505.92069634, 11112468.85262696,  2876803.94947864,
#         3231672.74327579,  3401851.73272715,  3817886.77882026,
#         6480945.38272576,  2916318.6945186 ,  5041786.02796789,
#         4604635.23223068,  3703695.40119218,  5965945.53533485,
#         6122591.64642047,  2791759.95866017,  4855963.7247457 ,
#         5576482.13667379,  8542790.29213908,  3251260.92102124,
#         5828055.71146127,  8859877.98610466,  3425115.78057427,
#         7098364.03548862,  3396843.5414542 ,  7521869.57984609,
#         4424392.03315496,  3795896.4614733 ,  6480099.09056362,
#         4914662.06889299,  4498658.87087891,  3291014.23832027,
#         5269147.46128353,  4876997.85266996,  3571640.9385677 ,
#         8043952.46153478,  4139909.74320416,  3927495.37703027,
#         4470289.37989716,  7484548.86041087,  4191766.09807028,
#         4105018.21687806,  3442771.18624668,  8165804.72257344,
#         2823854.89354456,  4668016.9764179 ,  4605162.26692034,
#         3850372.27676417,  2756169.913931  ,  8288356.69064202,
#         2956239.05067336,  4506113.52578325,  2836818.35379557,
#         5352556.19794131,  4156014.76604002,  5297811.50824147,
#         4361672.67444641,  4920917.64411281,  4711854.46404089,
#         7980539.33231654,  3528438.81006967,  6367312.21554533,
#         6448801.82888746,  5392432.18257742,  5384424.86667881,
#         4856008.95612189,  9067894.29387032,  3515111.08302021,
#         6186174.80651499,  3985181.15727194,  4765543.67950935,
#         5056357.10004812,  4464003.84053327,  8608518.97873296,
#         4119461.14277479,  7249247.15525715,  5659691.51714617,
#         2747359.07322448,  8161957.79275735,  2669375.87332412,
#         3705712.64909452,  8924822.94458412,  9428886.22198624,
#         3307178.74585047,  6294383.57835794,  3749972.53718247,
#         3886746.52330982,  9225924.88914408,  4914608.07757047,
#         5366101.84037385,  7214471.74858249,  5143160.29008919,
#         6813387.69528167,  3868805.16983614,  7149399.48843801,
#         3742947.31504475,  7119707.71712033,  5216506.3469588 ,
#         4718674.95017498,  7841262.86169982,  7131005.81108793,
#         7195140.37030107])

# %%
y_test
# Out:
# 316    4060000
# 77     6650000
# 360    3710000
# 90     6440000
# 493    2800000
#         ...
# 15     9100000
# 357    3773000
# 39     7910000
# 54     7350000
# 155    5530000
# Name: price, Length: 109, dtype: int64

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
import math

# %%
r2= r2_score(y_test,y_pred)
r2
# Out:
# 0.6233608143552076

# %%
mse= mean_squared_error(y_pred,y_test)
mse
# Out:
# 1903749221373.3274

# %%
rmse= math.sqrt(mse)
rmse
# Out:
# 1379764.1904953641

# %%
mae= mean_absolute_error(y_pred,y_test)
mae
# Out:
# 1057675.1454856389

# %% [markdown]
# # End of this section
